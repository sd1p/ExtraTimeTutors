# %%
# !pip install gensim
# !pip install git+https://github.com/boudinfl/pke.git
# !pip install flashtext
# !pip install pywsd
#!pip install pyngrok
#!pip install pipreqs
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gensim in /usr/local/lib/python3.9/dist-packages (4.3.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.9/dist-packages (from gensim) (1.22.4)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.9/dist-packages (from gensim) (1.10.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.9/dist-packages (from gensim) (6.3.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/boudinfl/pke.git
#   Cloning https://github.com/boudinfl/pke.git to /tmp/pip-req-build-st_fmkwi
#   Running command git clone --filter=blob:none --quiet https://github.com/boudinfl/pke.git /tmp/pip-req-build-st_fmkwi
#   Resolved https://github.com/boudinfl/pke.git to commit f2d4f5d2252c64d23defccd32fdac8809cfd7ce0
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: nltk in /usr/local/lib/python3.9/dist-packages (from pke==2.0.0) (3.8.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/dist-packages (from pke==2.0.0) (3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from pke==2.0.0) (1.22.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from pke==2.0.0) (1.10.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.9/dist-packages (from pke==2.0.0) (1.2.2)
# Collecting unidecode
#   Downloading Unidecode-1.3.6-py3-none-any.whl (235 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.9/235.9 KB 13.5 MB/s eta 0:00:00
# Requirement already satisfied: future in /usr/local/lib/python3.9/dist-packages (from pke==2.0.0) (0.18.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.9/dist-packages (from pke==2.0.0) (1.1.1)
# Requirement already satisfied: spacy>=3.2.3 in /usr/local/lib/python3.9/dist-packages (from pke==2.0.0) (3.5.1)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from spacy>=3.2.3->pke==2.0.0) (1.0.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.9/dist-packages (from spacy>=3.2.3->pke==2.0.0) (4.65.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.9/dist-packages (from spacy>=3.2.3->pke==2.0.0) (2.4.6)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.9/dist-packages (from spacy>=3.2.3->pke==2.0.0) (8.1.9)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.9/dist-packages (from spacy>=3.2.3->pke==2.0.0) (3.0.12)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from spacy>=3.2.3->pke==2.0.0) (3.0.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.9/dist-packages (from spacy>=3.2.3->pke==2.0.0) (2.0.8)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.9/dist-packages (from spacy>=3.2.3->pke==2.0.0) (0.10.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.9/dist-packages (from spacy>=3.2.3->pke==2.0.0) (2.27.1)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.9/dist-packages (from spacy>=3.2.3->pke==2.0.0) (6.3.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.9/dist-packages (from spacy>=3.2.3->pke==2.0.0) (2.0.7)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.9/dist-packages (from spacy>=3.2.3->pke==2.0.0) (1.10.7)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.9/dist-packages (from spacy>=3.2.3->pke==2.0.0) (1.0.9)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.9/dist-packages (from spacy>=3.2.3->pke==2.0.0) (0.7.0)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.9/dist-packages (from spacy>=3.2.3->pke==2.0.0) (1.1.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from spacy>=3.2.3->pke==2.0.0) (67.6.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from spacy>=3.2.3->pke==2.0.0) (3.3.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from spacy>=3.2.3->pke==2.0.0) (3.1.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from spacy>=3.2.3->pke==2.0.0) (23.0)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from nltk->pke==2.0.0) (8.1.3)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.9/dist-packages (from nltk->pke==2.0.0) (2022.10.31)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->pke==2.0.0) (3.1.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.9/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy>=3.2.3->pke==2.0.0) (4.5.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3.2.3->pke==2.0.0) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3.2.3->pke==2.0.0) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3.2.3->pke==2.0.0) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3.2.3->pke==2.0.0) (1.26.15)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.9/dist-packages (from thinc<8.2.0,>=8.1.8->spacy>=3.2.3->pke==2.0.0) (0.0.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.9/dist-packages (from thinc<8.2.0,>=8.1.8->spacy>=3.2.3->pke==2.0.0) (0.7.9)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->spacy>=3.2.3->pke==2.0.0) (2.1.2)
# Building wheels for collected packages: pke
#   Building wheel for pke (setup.py) ... done
#   Created wheel for pke: filename=pke-2.0.0-py3-none-any.whl size=6160676 sha256=e35be2f92f545e117d3ecf224c551f99e08b6d25ca605eb21a5710cca93804f8
#   Stored in directory: /tmp/pip-ephem-wheel-cache-kxeoy1es/wheels/d5/46/97/85535b5b449f70b6a3c8d1138ce8587345876891e25bfe7954
# Successfully built pke
# Installing collected packages: unidecode, pke
# Successfully installed pke-2.0.0 unidecode-1.3.6
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting flashtext
#   Downloading flashtext-2.7.tar.gz (14 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: flashtext
#   Building wheel for flashtext (setup.py) ... done
#   Created wheel for flashtext: filename=flashtext-2.7-py2.py3-none-any.whl size=9308 sha256=08a7c57f53d0541287b8dc0480250565b404dc0521c76058fa17eeb18a8c93a3
#   Stored in directory: /root/.cache/pip/wheels/65/3c/c7/44672c5062c16d05760b1eaddbf611d2f6a4b715c6d6777418
# Successfully built flashtext
# Installing collected packages: flashtext
# Successfully installed flashtext-2.7
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pywsd
#   Downloading pywsd-1.2.5-py3-none-any.whl (26.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.9/26.9 MB 43.0 MB/s eta 0:00:00
# Collecting wn==0.0.23
#   Downloading wn-0.0.23.tar.gz (31.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.6/31.6 MB 14.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: nltk in /usr/local/lib/python3.9/dist-packages (from pywsd) (3.8.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from pywsd) (1.22.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from pywsd) (1.4.4)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from pywsd) (1.16.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.9/dist-packages (from nltk->pywsd) (2022.10.31)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from nltk->pywsd) (4.65.0)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from nltk->pywsd) (8.1.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.9/dist-packages (from nltk->pywsd) (1.1.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->pywsd) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->pywsd) (2022.7.1)
# Building wheels for collected packages: wn
#   Building wheel for wn (setup.py) ... done
#   Created wheel for wn: filename=wn-0.0.23-py3-none-any.whl size=31792928 sha256=01027b09bf939f938ad93e718bc3e49fc35c8e64cfe014f5aa3de3f415f7615a
#   Stored in directory: /root/.cache/pip/wheels/cd/8b/7d/c44f094ca392bd08edcd90adf241a3484b75e2b8e205fab50a
# Successfully built wn
# Installing collected packages: wn, pywsd
# Successfully installed pywsd-1.2.5 wn-0.0.23

# %%
import nltk
nltk.download('stopwords')
nltk.download('popular')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cmudict.zip.
# [nltk_data]    | Downloading package gazetteers to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gazetteers.zip.
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/genesis.zip.
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gutenberg.zip.
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/inaugural.zip.
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/movie_reviews.zip.
# [nltk_data]    | Downloading package names to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/names.zip.
# [nltk_data]    | Downloading package shakespeare to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/shakespeare.zip.
# [nltk_data]    | Downloading package stopwords to /root/nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package treebank to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/treebank.zip.
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/twitter_samples.zip.
# [nltk_data]    | Downloading package omw to /root/nltk_data...
# [nltk_data]    | Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet2021 to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet31 to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet_ic to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet_ic.zip.
# [nltk_data]    | Downloading package words to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/words.zip.
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data]    | Downloading package punkt to /root/nltk_data...
# [nltk_data]    |   Unzipping tokenizers/punkt.zip.
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    |
# [nltk_data]  Done downloading collection popular
# True

# %%
# !pip install youtube_transcript_api
# !pip install sorcery
# !pip install flask_cors
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting youtube_transcript_api
#   Downloading youtube_transcript_api-0.5.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from youtube_transcript_api) (2.27.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->youtube_transcript_api) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->youtube_transcript_api) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->youtube_transcript_api) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->youtube_transcript_api) (3.4)
# Installing collected packages: youtube_transcript_api
# Successfully installed youtube_transcript_api-0.5.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sorcery
#   Downloading sorcery-0.2.2-py3-none-any.whl (16 kB)
# Collecting asttokens
#   Downloading asttokens-2.2.1-py2.py3-none-any.whl (26 kB)
# Collecting littleutils>=0.2.1
#   Downloading littleutils-0.2.2.tar.gz (6.6 kB)
#   Preparing metadata (setup.py) ... done
# Collecting executing
#   Downloading executing-1.2.0-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.9/dist-packages (from sorcery) (1.14.1)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from asttokens->sorcery) (1.16.0)
# Building wheels for collected packages: littleutils
#   Building wheel for littleutils (setup.py) ... done
#   Created wheel for littleutils: filename=littleutils-0.2.2-py3-none-any.whl size=7048 sha256=288a313f9f0a205f68a88a17567cfb4a0095ab8da421eb2329afea6195551e17
#   Stored in directory: /root/.cache/pip/wheels/04/bb/0d/2d02ec45f29c48d6192476bfb59c5a0e64b605e7212374dd15
# Successfully built littleutils
# Installing collected packages: littleutils, executing, asttokens, sorcery
# Successfully installed asttokens-2.2.1 executing-1.2.0 littleutils-0.2.2 sorcery-0.2.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting flask_cors
#   Downloading Flask_Cors-3.0.10-py2.py3-none-any.whl (14 kB)
# Requirement already satisfied: Six in /usr/local/lib/python3.9/dist-packages (from flask_cors) (1.16.0)
# Requirement already satisfied: Flask>=0.9 in /usr/local/lib/python3.9/dist-packages (from flask_cors) (2.2.3)
# Requirement already satisfied: Werkzeug>=2.2.2 in /usr/local/lib/python3.9/dist-packages (from Flask>=0.9->flask_cors) (2.2.3)
# Requirement already satisfied: importlib-metadata>=3.6.0 in /usr/local/lib/python3.9/dist-packages (from Flask>=0.9->flask_cors) (6.1.0)
# Requirement already satisfied: Jinja2>=3.0 in /usr/local/lib/python3.9/dist-packages (from Flask>=0.9->flask_cors) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.9/dist-packages (from Flask>=0.9->flask_cors) (2.1.2)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.9/dist-packages (from Flask>=0.9->flask_cors) (8.1.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata>=3.6.0->Flask>=0.9->flask_cors) (3.15.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from Jinja2>=3.0->Flask>=0.9->flask_cors) (2.1.2)
# Installing collected packages: flask_cors
# Successfully installed flask_cors-3.0.10

# %%
from flask import Flask, request, jsonify
from os import path
from flask_cors import CORS
from urllib.parse import urlparse
from urllib.parse import parse_qs
from youtube_transcript_api import YouTubeTranscriptApi
from sorcery import dict_of
import re
import pke
import string
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize
from nltk.corpus import wordnet as wn
from flashtext import KeywordProcessor 
import requests
import json
import random
from pywsd.similarity import max_similarity
from pywsd.lesk import adapted_lesk
# Out:
# /usr/local/lib/python3.9/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# Warming up PyWSD (takes ~10 secs)... took 6.087073802947998 secs.

# %%
def summarize(text):
  payload={"inputs":text}
  API_URL_sum = "https://api-inference.huggingface.co/models/gavin124/gpt2-finetuned-cnn-summarization-v2"
  headers_sum = {"Authorization": "Bearer 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"}
  response = requests.post(API_URL_sum, headers=headers_sum, json=payload)
  output=response.json()[0]["summary_text"]
  print(output)
  return output

  
#summarize("hey hello there")

def mainModel(context):
  full_text = context
  summ_text = summarize(full_text)
  print(summ_text)

  def get_nouns(text):
    P_nouns=[]
    extractor = pke.unsupervised.MultipartiteRank()
    stoplist = list(string.punctuation)
    stoplist += ['-lrb-', '-rrb-', '-lcb-', '-rcb-', '-lsb-', '-rsb-']
    stoplist += stopwords.words('english')
    extractor.load_document(input=text, stoplist=stoplist)
    pos = {'NOUN'} ##Here we using parts of speech as proper noun
    extractor.candidate_selection(pos=pos)
    extractor.candidate_weighting(alpha=1.1, threshold=0.75, method='average')
    keyphrases = extractor.get_n_best(n=20)
    for key in keyphrases:
      P_nouns.append(key[0])

    return P_nouns


  keywords = get_nouns(full_text)
  print(keywords)

  summ_keys=[]
  for keyword in keywords:
    if keyword.lower() in summ_text.lower():
      summ_keys.append(keyword)
  
  print(summ_keys)


  def tokenize_sent(text):
    sentences = [sent_tokenize(text)] ## sent_tokenize already ek list deta hai to yaha par 2d list ban ja rhi hai
    sentences = [y for x in sentences for y in x] 
    sentences = [sentence.strip() for sentence in sentences if len(sentence) > 12]  ##remove sentences with length less than ~
    return sentences

  def get_keyword_sentences(keywords, sentences):
    keyword_processor = KeywordProcessor()
    keyword_sentences = {}
    for word in keywords:
      keyword_sentences[word] = []
      keyword_processor.add_keyword(word)
    for sentence in sentences:
      keyword_found = keyword_processor.extract_keywords(sentence)
      for key in keyword_found:
        keyword_sentences[key].append(sentence)
    for key in keyword_sentences.keys():
      values = keyword_sentences[key]
      values = sorted(values,  key=len, reverse=True) ##reverse is for ascending descending
      keyword_sentences[key] = values
    return keyword_sentences

  sentences = tokenize_sent(summ_text)
  keyword_sentence_mapping = get_keyword_sentences(summ_keys, sentences)

  print(keyword_sentence_mapping)

  for keyword in keyword_sentence_mapping:
    if len(keyword_sentence_mapping[keyword])>0:  
      print(keyword_sentence_mapping[keyword][0])


  def get_distractors(syn,word):
    distractors=[]
    word=word.lower()
    og_word = word
    if len(word.split())>0:
      word=word.replace(" ","_")
    hypernym = syn.hypernyms()
    if len(hypernym) == 0:
      return distractors
    for item in hypernym[0].hyponyms():
      name = item.lemmas()[0].name()
      if name == og_word:
        continue
      name = name.replace("_"," ")
      name = " ".join(w.capitalize() for w in name.split())
      if name is not None and name not in distractors:
        distractors.append(name)
    return distractors

  def get_wordsense(sent,word):
      word= word.lower()
    
      if len(word.split())>0:
          word = word.replace(" ","_")

      synsets = wn.synsets(word,'n')
      if synsets:
          wup = max_similarity(sent, word, 'wup', pos='n')
          adapted_lesk_output =  adapted_lesk(sent, word, pos='n')
          lowest_index = min (synsets.index(wup),synsets.index(adapted_lesk_output))
          return synsets[lowest_index]
      else:
          return None

  key_distractor_list = {}

  for keyword in keyword_sentence_mapping:
      if len(keyword_sentence_mapping[keyword])>0:
        wordsense = get_wordsense(keyword_sentence_mapping[keyword][0],keyword)
        if wordsense:
            distractors = get_distractors(wordsense,keyword)
            if len(distractors) != 0:
                key_distractor_list[keyword] = distractors
                #print(key_distractor_list)
  questions=[]
  index = 1
  for quest in key_distractor_list:

    sentence = keyword_sentence_mapping[quest][0]
    pattern = re.compile(quest, re.IGNORECASE)
    output = pattern.sub( " _______ ", sentence)
    print (index,")",output)
    if quest.capitalize() in key_distractor_list[quest]:
      key_distractor_list[quest].remove(quest.capitalize())
    choices = [quest.capitalize()] + key_distractor_list[quest]
    top4choices = choices[:4]
    random.shuffle(top4choices)
    optionchoices = ['a','b','c','d']
    for idx,choice in enumerate(top4choices):
        print ("\t",optionchoices[idx],")"," ",choice)
    print ("\nMore options: ", choices[4:20],"\n\n")
    id=index
    question=output
    options=top4choices
    answer=options.index(quest.capitalize())
    res_dict = dict_of(id,question,options,answer)
    #print(id,options,question,answer)
    questions.append(res_dict)
    #print(res_dict)
    index = index + 1
  print(questions) 
  return questions   
    
mainModel("Mahatma Gandhi, also known as Mohandas Karamchand Gandhi, was an Indian independence leader who played a significant role in India's struggle for freedom from British rule. He was born on October 2, 1869, in Porbandar, Gujarat, India. Gandhi was a lawyer by profession, but he is best known for his non-violent civil disobedience approach to achieving political and social change. He began his political activism in South Africa, where he fought against discriminatory laws against Indians. He later returned to India in 1915 and became the leader of the Indian National Congress, which was at the forefront of the independence movement. Gandhi's philosophy of non-violent resistance, known as Satyagraha, influenced many movements for civil rights and freedom around the world, including the American civil rights movement led by Martin Luther King Jr. He believed that non-violent protest could achieve social and political change without resorting to violence or aggression. Gandhi's most significant contribution to India's struggle for independence was the Salt March of 1930. The British had imposed a salt tax, making it illegal for Indians to produce or sell salt. Gandhi led a 240-mile march to the Arabian Sea to collect salt, which galvanized the Indian people and brought international attention to their cause. Gandhi's legacy continues to inspire people around the world. He believed in the power of the individual to bring about change, and his teachings on non-violence and civil disobedience continue to influence social and political movements to this day. He was assassinated on January 30, 1948, but his ideas and philosophy live on, and he remains one of the most revered and respected figures in modern history.")
# Out:
# Mahatma Gandhi, also known as Mohandas Karamchand Gandhi, was an Indian independence leader who played a significant role in India's struggle for freedom from British rule. He was born on October 2, 1869, in Porbandar, Gujarat, India. Gandhi was a lawyer by profession, but he is best known for his non-violent civil disobedience approach to achieving political and social change. He began his political activism in South Africa, where he fought against discriminatory laws against Indians. He later returned to India in 1915 and became the leader of the Indian National Congress, which was at the forefront of the independence movement. Gandhi's philosophy of non-violent resistance, known as Satyagraha, influenced many movements for civil rights and freedom around the world, including the American civil rights movement led by Martin Luther King Jr. He believed that non-violent protest could achieve social and political change without resorting to violence or aggression. Gandhi's most significant contribution to India's struggle for independence was the Salt March of 1930. The British had imposed a salt tax, making it illegal for Indians to produce or sell salt. Gandhi led a 240-mile march to the Arabian Sea to collect salt, which galvanized the Indian people and brought international attention to their cause. Gandhi's legacy continues to inspire people around the world. He believed in the power of the individual to bring about change, and his teachings on non-violence and civil disobedience continue to influence social and political movements to this day. He was assassinated on January 30, 1948, but his ideas and philosophy live on, and he remains one of the most revered and respected figures in modern history.
# Mahatma Gandhi, also known as Mohandas Karamchand Gandhi, was an Indian independence leader who played a significant role in India's struggle for freedom from British rule. He was born on October 2, 1869, in Porbandar, Gujarat, India. Gandhi was a lawyer by profession, but he is best known for his non-violent civil disobedience approach to achieving political and social change. He began his political activism in South Africa, where he fought against discriminatory laws against Indians. He later returned to India in 1915 and became the leader of the Indian National Congress, which was at the forefront of the independence movement. Gandhi's philosophy of non-violent resistance, known as Satyagraha, influenced many movements for civil rights and freedom around the world, including the American civil rights movement led by Martin Luther King Jr. He believed that non-violent protest could achieve social and political change without resorting to violence or aggression. Gandhi's most significant contribution to India's struggle for independence was the Salt March of 1930. The British had imposed a salt tax, making it illegal for Indians to produce or sell salt. Gandhi led a 240-mile march to the Arabian Sea to collect salt, which galvanized the Indian people and brought international attention to their cause. Gandhi's legacy continues to inspire people around the world. He believed in the power of the individual to bring about change, and his teachings on non-violence and civil disobedience continue to influence social and political movements to this day. He was assassinated on January 30, 1948, but his ideas and philosophy live on, and he remains one of the most revered and respected figures in modern history.
# ['independence movement', 'change', 'freedom', 'independence leader', 'struggle', 'rights', 'philosophy', 'world', 'salt tax', 'movements', 'people', 'disobedience approach', 'forefront', 'salt', 'role', 'resistance', 'violence', 'aggression', 'profession', 'lawyer']
# ['independence movement', 'change', 'freedom', 'independence leader', 'struggle', 'rights', 'philosophy', 'world', 'salt tax', 'movements', 'people', 'disobedience approach', 'forefront', 'salt', 'role', 'resistance', 'violence', 'aggression', 'profession', 'lawyer']
# {'independence movement': ['He later returned to India in 1915 and became the leader of the Indian National Congress, which was at the forefront of the independence movement.'], 'change': ['He believed in the power of the individual to bring about change, and his teachings on non-violence and civil disobedience continue to influence social and political movements to this day.', 'Gandhi was a lawyer by profession, but he is best known for his non-violent civil disobedience approach to achieving political and social change.', 'He believed that non-violent protest could achieve social and political change without resorting to violence or aggression.'], 'freedom': ["Gandhi's philosophy of non-violent resistance, known as Satyagraha, influenced many movements for civil rights and freedom around the world, including the American civil rights movement led by Martin Luther King Jr.", "Mahatma Gandhi, also known as Mohandas Karamchand Gandhi, was an Indian independence leader who played a significant role in India's struggle for freedom from British rule."], 'independence leader': ["Mahatma Gandhi, also known as Mohandas Karamchand Gandhi, was an Indian independence leader who played a significant role in India's struggle for freedom from British rule."], 'struggle': ["Mahatma Gandhi, also known as Mohandas Karamchand Gandhi, was an Indian independence leader who played a significant role in India's struggle for freedom from British rule.", "Gandhi's most significant contribution to India's struggle for independence was the Salt March of 1930."], 'rights': ["Gandhi's philosophy of non-violent resistance, known as Satyagraha, influenced many movements for civil rights and freedom around the world, including the American civil rights movement led by Martin Luther King Jr.", "Gandhi's philosophy of non-violent resistance, known as Satyagraha, influenced many movements for civil rights and freedom around the world, including the American civil rights movement led by Martin Luther King Jr."], 'philosophy': ["Gandhi's philosophy of non-violent resistance, known as Satyagraha, influenced many movements for civil rights and freedom around the world, including the American civil rights movement led by Martin Luther King Jr.", 'He was assassinated on January 30, 1948, but his ideas and philosophy live on, and he remains one of the most revered and respected figures in modern history.'], 'world': ["Gandhi's philosophy of non-violent resistance, known as Satyagraha, influenced many movements for civil rights and freedom around the world, including the American civil rights movement led by Martin Luther King Jr.", "Gandhi's legacy continues to inspire people around the world."], 'salt tax': ['The British had imposed a salt tax, making it illegal for Indians to produce or sell salt.'], 'movements': ["Gandhi's philosophy of non-violent resistance, known as Satyagraha, influenced many movements for civil rights and freedom around the world, including the American civil rights movement led by Martin Luther King Jr.", 'He believed in the power of the individual to bring about change, and his teachings on non-violence and civil disobedience continue to influence social and political movements to this day.'], 'people': ['Gandhi led a 240-mile march to the Arabian Sea to collect salt, which galvanized the Indian people and brought international attention to their cause.', "Gandhi's legacy continues to inspire people around the world."], 'disobedience approach': ['Gandhi was a lawyer by profession, but he is best known for his non-violent civil disobedience approach to achieving political and social change.'], 'forefront': ['He later returned to India in 1915 and became the leader of the Indian National Congress, which was at the forefront of the independence movement.'], 'salt': ['Gandhi led a 240-mile march to the Arabian Sea to collect salt, which galvanized the Indian people and brought international attention to their cause.', "Gandhi's most significan ...
# He later returned to India in 1915 and became the leader of the Indian National Congress, which was at the forefront of the independence movement.
# He believed in the power of the individual to bring about change, and his teachings on non-violence and civil disobedience continue to influence social and political movements to this day.
# Gandhi's philosophy of non-violent resistance, known as Satyagraha, influenced many movements for civil rights and freedom around the world, including the American civil rights movement led by Martin Luther King Jr.
# Mahatma Gandhi, also known as Mohandas Karamchand Gandhi, was an Indian independence leader who played a significant role in India's struggle for freedom from British rule.
# Mahatma Gandhi, also known as Mohandas Karamchand Gandhi, was an Indian independence leader who played a significant role in India's struggle for freedom from British rule.
# Gandhi's philosophy of non-violent resistance, known as Satyagraha, influenced many movements for civil rights and freedom around the world, including the American civil rights movement led by Martin Luther King Jr.
# Gandhi's philosophy of non-violent resistance, known as Satyagraha, influenced many movements for civil rights and freedom around the world, including the American civil rights movement led by Martin Luther King Jr.
# Gandhi's philosophy of non-violent resistance, known as Satyagraha, influenced many movements for civil rights and freedom around the world, including the American civil rights movement led by Martin Luther King Jr.
# The British had imposed a salt tax, making it illegal for Indians to produce or sell salt.
# Gandhi's philosophy of non-violent resistance, known as Satyagraha, influenced many movements for civil rights and freedom around the world, including the American civil rights movement led by Martin Luther King Jr.
# Gandhi led a 240-mile march to the Arabian Sea to collect salt, which galvanized the Indian people and brought international attention to their cause.
# Gandhi was a lawyer by profession, but he is best known for his non-violent civil disobedience approach to achieving political and social change.
# He later returned to India in 1915 and became the leader of the Indian National Congress, which was at the forefront of the independence movement.
# Gandhi led a 240-mile march to the Arabian Sea to collect salt, which galvanized the Indian people and brought international attention to their cause.
# Mahatma Gandhi, also known as Mohandas Karamchand Gandhi, was an Indian independence leader who played a significant role in India's struggle for freedom from British rule.
# Gandhi's philosophy of non-violent resistance, known as Satyagraha, influenced many movements for civil rights and freedom around the world, including the American civil rights movement led by Martin Luther King Jr.
# He believed in the power of the individual to bring about change, and his teachings on non-violence and civil disobedience continue to influence social and political movements to this day.
# He believed that non-violent protest could achieve social and political change without resorting to violence or aggression.
# Gandhi was a lawyer by profession, but he is best known for his non-violent civil disobedience approach to achieving political and social change.
# Gandhi was a lawyer by profession, but he is best known for his non-violent civil disobedience approach to achieving political and social change.
# 1 ) He believed in the power of the individual to bring about  _______ , and his teachings on non-violence and civil disobedience continue to influence social and political movements to this day.
# 	 a )   Accomplishment
# 	 b )   Aggression
# 	 c )   Alienation
# 	 d )   Change
#
# More options:  ['Application', 'Arrival', 'Beatification', 'Bruxism', 'Choice', 'Course', 'Destabilization', 'Economy', 'Emphasizing', 'Employment', 'Fetch', 'Interaction', 'Jumpstart', 'Kindness', 'Performance', 'Pickings']
#
#
# 2 ) Gandhi's philosophy of non-violent resistance, known as Satyagraha, influenced many movements for civil rights and  _______  around the world, including the American civil rights movement led by Martin Luther King Jr.
# 	 a )   Being
# 	 b )   Freedom
# 	 c )   Action
# 	 d )   Cleavage
#
# More options:  ['Condition', 'Conditionality', 'Conflict', 'Damnation', 'Dead Letter', 'Death', 'Degree', 'Dependence', 'Disorder', 'Dystopia', 'Employment', 'End', 'Enlargement', 'Feeling', 'Flux', 'Grace']
#
#
# 3 ) Mahatma Gandhi, also known as Mohandas Karamchand Gandhi, was an Indian independence leader who played a significant role in India's  _______  for freedom from British rule.
# 	 a )   Struggle
# 	 b )   Attendance
# 	 c )   Action
# 	 d )   Assembly
#
# More options:  ['Brainstorming', 'Communalism', 'Competition', 'Confederation', 'Conflict', 'Cooperation', "Coup D'etat", 'Decolonization', 'Democratization', 'Disbandment', 'Disestablishment', 'Due Process', 'Engagement', 'Ethnic Cleansing', 'Exchange', 'Integration']
#
#
# 4 ) Gandhi's philosophy of non-violent resistance, known as Satyagraha, influenced many movements for civil  _______  and freedom around the world, including the American civil  _______  movement led by Martin Luther King Jr.
# 	 a )   Teacher
# 	 b )   Rights
# 	 c )   Absolute
# 	 d )   Right
#
# More options:  ['Thing']
#
#
# 5 ) Gandhi's  _______  of non-violent resistance, known as Satyagraha, influenced many movements for civil rights and freedom around the world, including the American civil rights movement led by Martin Luther King Jr.
# 	 a )   Autotelism
# 	 b )   Doctrine
# 	 c )   Conviction
# 	 d )   Philosophy
#
# More options:  ['Expectation', 'Faith', 'Fetishism', 'Geneticism', 'Individualism', 'Meliorism', 'Opinion', 'Originalism', 'Pacifism', 'Public Opinion', 'Religion', 'Revolutionism', 'Sacerdotalism', 'Spiritual Being', 'Spiritual World', 'Spiritualism']
#
#
# 6 ) Gandhi's philosophy of non-violent resistance, known as Satyagraha, influenced many  _______  for civil rights and freedom around the world, including the American civil rights movement led by Martin Luther King Jr.
# 	 a )   Movements
# 	 b )   Congregation
# 	 c )   Force
# 	 d )   Body
#
# More options:  ['Fringe', 'Gathering', 'Interest', 'Jewry', 'Kin', 'Kith', 'Minority', 'Moiety', 'Movement', 'Nonalignment', 'Organization', 'Organized Crime', 'Phylum', 'Platoon', 'Political System', 'Revolving Door']
#
#
# 7 ) Gandhi led a 240-mile march to the Arabian Sea to collect salt, which galvanized the Indian  _______  and brought international attention to their cause.
# 	 a )   Actinoid
# 	 b )   Arrangement
# 	 c )   Association
# 	 d )   People
#
# More options:  ['Biological Group', 'Circuit', 'Citizenry', 'Collection', 'Community', 'Edition', 'Electron Shell', 'Ethnic Group', 'Halogen', 'Kingdom', 'Multitude', 'Population', 'Race', 'Rare Earth', 'Sainthood', 'Series']
#
#
# 8 ) Gandhi led a 240-mile march to the Arabian Sea to collect  _______ , which galvanized the Indian people and brought international attention to their cause.
# 	 a )   Acid
# 	 b )   Acceptor
# 	 c )   Adduct
# 	 d )   Salt
#
# More options:  ['Allomorph', 'Aluminate', 'Ammine', 'Anhydride', 'Anionic Compound', 'Antiknock', 'Arsenide', 'Azide', 'Base', 'Benzofuran', 'Binary Compound', 'Bitter Principle', 'Buffer', 'Calcium-cyanamide', 'Carbon Disulfide', 'Carbonyl']
#
#
# 9 ) Mahatma Gandhi, also known as Mohandas Karamchand Gandhi, was an Indian independence leader who played a significant  _______  in India's struggle for freedom from British rule.
# 	 a )   Assignment
# 	 b )   Job
# 	 c )   Role
# 	 d )   Function
#
# More options:  []
#
#
# 10 ) Gandhi's philosophy of non-violent  _______ , known as Satyagraha, influenced many movements for civil rights and freedom around the world, including the American civil rights movement led by Martin Luther King Jr.
# 	 a )   Resistance
# 	 b )   Aggression
# 	 c )   Alienation
# 	 d )   Accomplishment
#
# More options:  ['Application', 'Arrival', 'Beatification', 'Bruxism', 'Change', 'Choice', 'Course', 'Destabilization', 'Economy', 'Emphasizing', 'Employment', 'Fetch', 'Interaction', 'Jumpstart', 'Kindness', 'Performance']
#
#
# 11 ) He believed in the power of the individual to bring about change, and his teachings on non- _______  and civil disobedience continue to influence social and political movements to this day.
# 	 a )   Plundering
# 	 b )   Violence
# 	 c )   Meat Grinder
#
# More options:  []
#
#
# 12 ) He believed that non-violent protest could achieve social and political change without resorting to violence or  _______ .
# 	 a )   Application
# 	 b )   Alienation
# 	 c )   Aggression
# 	 d )   Accomplishment
#
# More options:  ['Arrival', 'Beatification', 'Bruxism', 'Change', 'Choice', 'Course', 'Destabilization', 'Economy', 'Emphasizing', 'Employment', 'Fetch', 'Interaction', 'Jumpstart', 'Kindness', 'Performance', 'Pickings']
#
#
# 13 ) Gandhi was a lawyer by  _______ , but he is best known for his non-violent civil disobedience approach to achieving political and social change.
# 	 a )   Profession
# 	 b )   Appointment
# 	 c )   Accountancy
# 	 d )   Career
#
# More options:  ['Catering', 'Confectionery', 'Employment', 'Farming', 'Game', 'Metier', 'Photography', 'Position', 'Sport', 'Trade', 'Treadmill']
#
#
# 14 ) Gandhi was a  _______  by profession, but he is best known for his non-violent civil disobedience approach to achieving political and social change.
# 	 a )   Careerist
# 	 b )   Critic
# 	 c )   Lawyer
# 	 d )   Craftsman
#
# More options:  ['Educator', 'Health Professional', 'Librarian', 'Practitioner', 'Publisher', 'Yuppie']
#
#
# [{'id': 1, 'question': 'He believed in the power of the individual to bring about  _______ , and his teachings on non-violence and civil disobedience continue to influence social and political movements to this day.', 'options': ['Accomplishment', 'Aggression', 'Alienation', 'Change'], 'answer': 3}, {'id': 2, 'question': "Gandhi's philosophy of non-violent resistance, known as Satyagraha, influenced many movements for civil rights and  _______  around the world, including the American civil rights movement led by Martin Luther King Jr.", 'options': ['Being', 'Freedom', 'Action', 'Cleavage'], 'answer': 1}, {'id': 3, 'question': "Mahatma Gandhi, also known as Mohandas Karamchand Gandhi, was an Indian independence leader who played a significant role in India's  _______  for freedom from British rule.", 'options': ['Struggle', 'Attendance', 'Action', 'Assembly'], 'answer': 0}, {'id': 4, 'question': "Gandhi's philosophy of non-violent resistance, known as Satyagraha, influenced many movements for civil  _______  and freedom around the world, including the American civil  _______  movement led by Martin Luther King Jr.", 'options': ['Teacher', 'Rights', 'Absolute', 'Right'], 'answer': 1}, {'id': 5, 'question': "Gandhi's  _______  of non-violent resistance, known as Satyagraha, influenced many movements for civil rights and freedom around the world, including the American civil rights movement led by Martin Luther King Jr.", 'options': ['Autotelism', 'Doctrine', 'Conviction', 'Philosophy'], 'answer': 3}, {'id': 6, 'question': "Gandhi's philosophy of non-violent resistance, known as Satyagraha, influenced many  _______  for civil rights and freedom around the world, including the American civil rights movement led by Martin Luther King Jr.", 'options': ['Movements', 'Congregation', 'Force', 'Body'], 'answer': 0}, {'id': 7, 'question': 'Gandhi led a 240-mile march to the Arabian Sea to collect salt, which galvanized the Indian  _______  and brought international attention to their cause.', 'options': ['Actinoid', 'Arrangement', 'Association', 'People'], 'answer': 3}, {'id': 8, 'question': 'Gandhi led a 240-mile march to the Arabian Sea to collect  _______ , which galvanized the Indian people and brought international attention to their cause.', 'options': ['Acid', 'Acceptor', 'Adduct', 'Salt'], 'answer': 3}, {'id': 9, 'question': "Mahatma Gandhi, also known as Mohandas Karamchand Gandhi, was an Indian independence leader who played a significant  _______  in India's struggle for freedom from British rule.", 'options': ['Assignment', 'Job', 'Role', 'Function'], 'answer': 2}, {'id': 10, 'question': "Gandhi's philosophy of non-violent  _______ , known as Satyagraha, influenced many movements for civil rights and freedom around the world, including the American civil rights movement led by Martin Luther King Jr.", 'options': ['Resistance', 'Aggression', 'Alienation', 'Accomplishment'], 'answer': 0}, {'id': 11, 'question': 'He believed in the power of the individual to bring about change, and his teachings on non- _______  and civil disobedience continue to influence social and political movements to this day.', 'options': ['Plundering', 'Violence', 'Meat Grinder'], 'answer': 1}, {'id': 12, 'question': 'He believed that non-violent protest could achieve social and political change without resorting to violence or  _______ .', 'options': ['Application', 'Alienation', 'Aggression', 'Accomplishment'], 'answer': 2}, {'id': 13, 'question': 'Gandhi was a lawyer by  _______ , but he is best known for his non-violent civil disobedience approach to achieving political and social change.', 'options': ['Profession', 'Appointment', 'Accountancy', 'Career'], 'answer': 0}, {'id': 14, 'question': 'Gandhi was a  _______  by profession, but he is best known for his non-violent civil disobedience approach to achieving political and social change.', 'options': ['Careerist', 'Critic', 'Lawyer', 'Craftsman'], 'answer': 2}]
# [{'id': 1,
#   'question': 'He believed in the power of the individual to bring about  _______ , and his teachings on non-violence and civil disobedience continue to influence social and political movements to this day.',
#   'options': ['Accomplishment', 'Aggression', 'Alienation', 'Change'],
#   'answer': 3},
#  {'id': 2,
#   'question': "Gandhi's philosophy of non-violent resistance, known as Satyagraha, influenced many movements for civil rights and  _______  around the world, including the American civil rights movement led by Martin Luther King Jr.",
#   'options': ['Being', 'Freedom', 'Action', 'Cleavage'],
#   'answer': 1},
#  {'id': 3,
#   'question': "Mahatma Gandhi, also known as Mohandas Karamchand Gandhi, was an Indian independence leader who played a significant role in India's  _______  for freedom from British rule.",
#   'options': ['Struggle', 'Attendance', 'Action', 'Assembly'],
#   'answer': 0},
#  {'id': 4,
#   'question': "Gandhi's philosophy of non-violent resistance, known as Satyagraha, influenced many movements for civil  _______  and freedom around the world, including the American civil  _______  movement led by Martin Luther King Jr.",
#   'options': ['Teacher', 'Rights', 'Absolute', 'Right'],
#   'answer': 1},
#  {'id': 5,
#   'question': "Gandhi's  _______  of non-violent resistance, known as Satyagraha, influenced many movements for civil rights and freedom around the world, including the American civil rights movement led by Martin Luther King Jr.",
#   'options': ['Autotelism', 'Doctrine', 'Conviction', 'Philosophy'],
#   'answer': 3},
#  {'id': 6,
#   'question': "Gandhi's philosophy of non-violent resistance, known as Satyagraha, influenced many  _______  for civil rights and freedom around the world, including the American civil rights movement led by Martin Luther King Jr.",
#   'options': ['Movements', 'Congregation', 'Force', 'Body'],
#   'answer': 0},
#  {'id': 7,
#   'question': 'Gandhi led a 240-mile march to the Arabian Sea to collect salt, which galvanized the Indian  _______  and brought international attention to their cause.',
#   'options': ['Actinoid', 'Arrangement', 'Association', 'People'],
#   'answer': 3},
#  {'id': 8,
#   'question': 'Gandhi led a 240-mile march to the Arabian Sea to collect  _______ , which galvanized the Indian people and brought international attention to their cause.',
#   'options': ['Acid', 'Acceptor', 'Adduct', 'Salt'],
#   'answer': 3},
#  {'id': 9,
#   'question': "Mahatma Gandhi, also known as Mohandas Karamchand Gandhi, was an Indian independence leader who played a significant  _______  in India's struggle for freedom from British rule.",
#   'options': ['Assignment', 'Job', 'Role', 'Function'],
#   'answer': 2},
#  {'id': 10,
#   'question': "Gandhi's philosophy of non-violent  _______ , known as Satyagraha, influenced many movements for civil rights and freedom around the world, including the American civil rights movement led by Martin Luther King Jr.",
#   'options': ['Resistance', 'Aggression', 'Alienation', 'Accomplishment'],
#   'answer': 0},
#  {'id': 11,
#   'question': 'He believed in the power of the individual to bring about change, and his teachings on non- _______  and civil disobedience continue to influence social and political movements to this day.',
#   'options': ['Plundering', 'Violence', 'Meat Grinder'],
#   'answer': 1},
#  {'id': 12,
#   'question': 'He believed that non-violent protest could achieve social and political change without resorting to violence or  _______ .',
#   'options': ['Application', 'Alienation', 'Aggression', 'Accomplishment'],
#   'answer': 2},
#  {'id': 13,
#   'question': 'Gandhi was a lawyer by  _______ , but he is best known for his non-violent civil disobedience approach to achieving political and social change.',
#   'options': ['Profession', 'Appointment', 'Accountancy', 'Career'],
#   'answer': 0},
#  {'id': 14,
#   'question': 'Gandhi was a  _______  by profession, but he is best known for his non-violent civil disobedience approach to achieving political and social change.',
#   'options': ['Careerist', 'Critic', 'Lawyer', 'Craftsman'],
#   'answer': 2}]

# %%
##########################PUNCHUATIONS####################

import os
import yaml
import torch
from torch import package
import pandas as pd

torch.hub.download_url_to_file('https://raw.githubusercontent.com/snakers4/silero-models/master/models.yml',
                               'latest_silero_models.yml',
                               progress=False)

with open('latest_silero_models.yml', 'r', encoding='utf8') as yaml_file:
    models = yaml.load(yaml_file, Loader=yaml.SafeLoader)
model_conf = models.get('te_models').get('latest')
model_url = model_conf.get('package')

model_dir = "downloaded_model"
os.makedirs(model_dir, exist_ok=True)
model_path = os.path.join(model_dir, os.path.basename(model_url))

if not os.path.isfile(model_path):
    torch.hub.download_url_to_file(model_url,
                                   model_path,
                                   progress=True)

imp = package.PackageImporter(model_path)
model = imp.load_pickle("te_model", "model")
example_texts = model.examples

def punchuate(text, lan='en'):
    return model.enhance_text(text, lan)
    
print(punchuate("done", lan='en')) #Testing with 'done'.

#Getting transcript from youtube video id and adding punchuations.
def video_context(video_id):
    srt = YouTubeTranscriptApi.get_transcript(video_id) 
    jsonSrt=json.dumps(srt)
    data = json.loads(jsonSrt)
    df = pd.json_normalize(data)

    df_final = df.text
    df_final = " ".join(df_final)
    result = re.sub(r'\[.+\]', '', df_final)
    return result
# Out:
#   0%|          | 0.00/87.5M [00:00<?, ?B/s]
# Done!

# %%
##################################API##############################

app = Flask(__name__)
CORS(app)

@app.route("/api/vid",methods=['POST','GET'])

def vid():
    if request.method=='POST':
        input_json = request.get_json()
        #print(request.content_type)
        #print(input_json['url'])
        url=input_json['url']
        parsed_url=urlparse(url)
        video_id=parse_qs(parsed_url.query)['v'][0]
        print(video_id)
        context=video_context(video_id)
        print(context)
        p_context=punchuate(context,lan='en')
        print("\n",p_context)
        questions= mainModel(p_context)
        return jsonify(questions)

    
    if request.method=='GET':
        print("get success")
        return jsonify({'success':'200'})
    
@app.route("/api/summ",methods=['POST','GET'])

def summ():
    if request.method=='POST':
        input_json = request.get_json()
        print(request.content_type)
        print(input_json['url'])
        url=input_json['url']
        parsed_url=urlparse(url)
        video_id=parse_qs(parsed_url.query)['v'][0]
        print(video_id)
        context=video_context(video_id)
        print(context)
        p_context=punchuate(context,lan='en')
        summarized=summarize(p_context)
        return jsonify({'summary':summarized})

    
    if request.method=='GET':
        print("get success")
        return jsonify({'success':'200'})
    
@app.route("/api/ques",methods=['POST','GET'])

def ques():
    if request.method=='POST':
        input_json = request.get_json()
        print(request.content_type)
        print(input_json['url'])
        url=input_json['url']
        p_context=punchuate(url,lan='en')
        questions= mainModel(p_context)
        return jsonify(questions)
    
    if request.method=='GET':
        print("get success")
        return jsonify({'success':'200'})
if __name__ == "__main__":
   app.run()

# if __name__ == "__main__":
#   app.run(host='127.0.0.1', port='8080')
# if __name__ == '__main__':
#     app.run(debug=True, port=os.getenv("PORT", default=5000))
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# INFO:werkzeug:Press CTRL+C to quit
